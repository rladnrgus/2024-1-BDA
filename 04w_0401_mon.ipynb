# %% [markdown]
# <a href="https://colab.research.google.com/github/rladnrgus/2024-1-BDA/blob/main/04w_0401_mon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 5.92 MiB/s, done.

# %%
import pandas as pd

# %%
s = pd.Series(['a', 'b', 'c','d'], index = [3, 2, 1, 4])
s
# Out:
# 3    a
# 2    b
# 1    c
# 4    d
# dtype: object

# %%
s.sort_index()
# Out:
# 1    c
# 2    b
# 3    a
# 4    d
# dtype: object

# %%
df = pd.DataFrame([1,2,3,4,5], index = [100,29,234,1,150])

# %%
df.sort_values('A')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-ffeaefc6e861> in <cell line: 1>()
# ----> 1 df.sort_values('A')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6910
#    6911             by = by[0]
# -> 6912             k = self._get_label_or_level_values(by, axis=axis)
#    6913
#    6914             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#
# KeyError: 'A'

# %%
import pandas as pd
exam = pd.read_csv('data/exam.csv')
exam.sample(frac=.2)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 19  20       5    78       83       58
# 8    9       3    20       98       15
# 15  16       4    58       98       65

# %%
exam.sample(5)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 15  16       4    58       98       65
# 5    6       2    50       89       98

# %%
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math > 50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('(nclass == 1) & (math >= 50)')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('nclass == 2 & english >= 80')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45

# %%
exam.query('english < 90 | science < 50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math >= 90 | english >= 90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
exam.query('nclass == 1 | nclass == 3 | nclass == 5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass in [1, 3, 5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
3 in [1, 2. 3. 4]
# Out:
#   File "<ipython-input-42-ce052db33bd0>", line 1
#     3 in [1, 2. 3. 4]
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# 43번과 44번은 같은 것

# %%
exam.query('nclass in [1, 3, 5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam['nclass'].isin([1, 3, 5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-05c30385d459> in <cell line: 1>()
# ----> 1 nclass2
#
# NameError: name 'nclass2' is not defined

# %%
exam[["nclass", "math"]]
# Out:
#     nclass  math
# 0        1    50
# 1        1    60
# 2        1    45
# 3        1    30
# 4        2    25
# 5        2    50
# 6        2    80
# 7        2    90
# 8        3    20
# 9        3    50
# 10       3    65
# 11       3    45
# 12       4    46
# 13       4    48
# 14       4    75
# 15       4    58
# 16       5    65
# 17       5    80
# 18       5    89
# 19       5    78

# %%
nclass2
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
nclass1 = exam.query('nclass == 1')

# %%
nclass2 = exam.query('nclass == 2')

# %%
nclass1["math"].mean()
# Out:
# 46.25

# %%
nclass1["math"].sum()
# Out:
# 185

# %%
# nclass가 1인 행 추출해 nclass1에 할당
nclass1 = exam[exam.nclass == 1]

# nclass가 2인 행 추출해 nclass2에 할당
nclass2 = exam[exam.nclass == 2]

# %%
nclass2.math.mean()
# Out:
# 61.25

# %%
df = pd.DataFrame({'sex'     : ['F', 'M', 'F', 'M'],
                   'country' : ['Korea', 'China', 'Japan', 'USA']})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japan
# 3   M     USA

# %%
# 전체 조건에 큰따옴표, 추출할 문자에 작은따옴표 사용
df.query("sex == 'F' & country == 'Korea'")
# Out:
#   sex country
# 0   F   Korea

# %%
df.query("sex == 'M' & country == 'China'")
# Out:
#   sex country
# 1   M   China

# %%
var = 2
exam.query('nclass == @var')

# %%
exam[exam.nclass == var]

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df

# %% [markdown]
# 6-3 필요한 변수만 추출하기

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[["math"]]
# Out:
#     math
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78

# %%
exam.query('math >= 50') \
           [['id', 'math']] \
           .head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %%
exam.query('math >= 50 & english >= 80') \
         [['id', 'math', 'english']].head()
# Out:
#    id  math  english
# 0   1    50       98
# 1   2    60       97
# 5   6    50       89
# 6   7    80       90
# 9  10    50       98

# %%
exam.query('math >= 50 & english >= 80')[['id', 'math', 'english']].head()
# Out:
#    id  math  english
# 0   1    50       98
# 1   2    60       97
# 5   6    50       89
# 6   7    80       90
# 9  10    50       98

# %%
# math가 50 이상인 행만 추출
# id, math 추출
# 앞부분 10행 추출
# exam.query('math >= 50')[['id', 'math']].head(10)
exam.query('math >= 50') \
           [['id', 'math']] \
           .head(10)

# %%
exam.query('math >= 50')[['id', 'math', 'english']].head(10)
# Out:
#     id  math  english
# 0    1    50       98
# 1    2    60       97
# 5    6    50       89
# 6    7    80       90
# 7    8    90       78
# 9   10    50       98
# 10  11    65       65
# 14  15    75       56
# 15  16    58       98
# 16  17    65       68
